# %%
import obspy
import numpy as np
import pandas as pd
from obspy.imaging.cm import obspy_sequential
from obspy.signal.tf_misfit import cwt
import matplotlib.pyplot as plt
import glob
import png

# %%
wave_data=glob.glob('/Users/Geopersian/Documents/KB/input__extract/convert_data/darb/2021/11/*.seed')
print(wave_data)
st = obspy.Stream()
for add in wave_data:
    st+= obspy.read(add)
af=st.plot(label = "plot1")
af.savefig('plot1.png')
# Out:
# ['/Users/Geopersian/Documents/KB/input__extract/convert_data/darb/2021/11\\GT.DARB.BHE_20211118_000000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/darb/2021/11\\GT.DARB.BHE_20211118_010000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/darb/2021/11\\GT.DARB.BHE_20211118_020000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/darb/2021/11\\GT.DARB.BHE_20211118_030000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/darb/2021/11\\GT.DARB.BHE_20211118_040000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/darb/2021/11\\GT.DARB.BHE_20211118_050000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/darb/2021/11\\GT.DARB.BHE_20211118_060000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/darb/2021/11\\GT.DARB.BHE_20211118_070000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/darb/2021/11\\GT.DARB.BHE_20211118_080000.seed', '/Users/Geopersi
# ...

# %%
wave_data=glob.glob('/Users/Geopersian/Documents/KB/input__extract/convert_data/mdad/2021/11/*.seed')
print(wave_data)
st = obspy.Stream()
for add in wave_data:
    st+= obspy.read(add)
bf=st.plot(label = "plot2")
bf.savefig('plot2.png')
# Out:
# ['/Users/Geopersian/Documents/KB/input__extract/convert_data/mdad/2021/11\\GT.MDAD.BHE_20211118_060000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mdad/2021/11\\GT.MDAD.BHE_20211118_070000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mdad/2021/11\\GT.MDAD.BHE_20211118_080000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mdad/2021/11\\GT.MDAD.BHE_20211118_090000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mdad/2021/11\\GT.MDAD.BHE_20211118_100000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mdad/2021/11\\GT.MDAD.BHE_20211118_110000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mdad/2021/11\\GT.MDAD.BHE_20211118_120000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mdad/2021/11\\GT.MDAD.BHE_20211118_130000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mdad/2021/11\\GT.MDAD.BHE_20211118_140000.seed', '/Users/Geopersi
# ...

# %%
wave_data=glob.glob('/Users/Geopersian/Documents/KB/input__extract/convert_data/mian/2021/11/*.seed')
print(wave_data)
st = obspy.Stream()
for add in wave_data:
    st+= obspy.read(add)
cf=st.plot(label = "plot3")
cf.savefig('plot3.png')
# Out:
# ['/Users/Geopersian/Documents/KB/input__extract/convert_data/mian/2021/11\\GT.MIAN.BHE_20211118_000000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mian/2021/11\\GT.MIAN.BHE_20211118_010000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mian/2021/11\\GT.MIAN.BHE_20211118_020000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mian/2021/11\\GT.MIAN.BHE_20211118_030000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mian/2021/11\\GT.MIAN.BHE_20211118_040000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mian/2021/11\\GT.MIAN.BHE_20211118_050000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mian/2021/11\\GT.MIAN.BHE_20211118_060000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mian/2021/11\\GT.MIAN.BHE_20211118_070000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/mian/2021/11\\GT.MIAN.BHE_20211118_080000.seed', '/Users/Geopersi
# ...

# %%
wave_data=glob.glob('/Users/Geopersian/Documents/KB/input__extract/convert_data/tnbl/2021/11/*.seed')
print(wave_data)
st = obspy.Stream()
for add in wave_data:
    st+= obspy.read(add)
df=st.plot(label = "plot4")
df.savefig('plot4.png')
# Out:
# ['/Users/Geopersian/Documents/KB/input__extract/convert_data/tnbl/2021/11\\GT.TNBL.BHE_20211118_000000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/tnbl/2021/11\\GT.TNBL.BHE_20211118_010000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/tnbl/2021/11\\GT.TNBL.BHE_20211118_020000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/tnbl/2021/11\\GT.TNBL.BHE_20211118_030000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/tnbl/2021/11\\GT.TNBL.BHE_20211118_040000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/tnbl/2021/11\\GT.TNBL.BHE_20211118_050000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/tnbl/2021/11\\GT.TNBL.BHE_20211118_060000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/tnbl/2021/11\\GT.TNBL.BHE_20211118_070000.seed', '/Users/Geopersian/Documents/KB/input__extract/convert_data/tnbl/2021/11\\GT.TNBL.BHE_20211118_080000.seed', '/Users/Geopersi
# ...

# %%
wave_data=glob.glob('/Users/Geopersian/Documents/KB/output_extract/*.mseed')
print(wave_data)
st = obspy.Stream()
for add in wave_data:
    st+= obspy.read(add)
ef=st.plot(label = "plot output")
ef.savefig('plot5.png')
# Out:
# ['/Users/Geopersian/Documents/KB/output_extract\\2021-11-18T00-31-09.mseed', '/Users/Geopersian/Documents/KB/output_extract\\2021-11-18T00-50-25.mseed', '/Users/Geopersian/Documents/KB/output_extract\\2021-11-18T00-50-57.mseed', '/Users/Geopersian/Documents/KB/output_extract\\2021-11-18T00-56-29.mseed', '/Users/Geopersian/Documents/KB/output_extract\\2021-11-18T01-05-03.mseed', '/Users/Geopersian/Documents/KB/output_extract\\2021-11-18T01-08-09.mseed', '/Users/Geopersian/Documents/KB/output_extract\\2021-11-18T01-08-56.mseed', '/Users/Geopersian/Documents/KB/output_extract\\2021-11-18T01-09-44.mseed', '/Users/Geopersian/Documents/KB/output_extract\\2021-11-18T01-16-54.mseed', '/Users/Geopersian/Documents/KB/output_extract\\2021-11-18T01-35-27.mseed', '/Users/Geopersian/Documents/KB/output_extract\\2021-11-18T02-03-43.mseed', '/Users/Geopersian/Documents/KB/output_extract\\2021-11-18T02-20-08.mseed', '/Users/Geopersian/Documents/KB/output_extract\\2021-11-18T02-21-36.mseed', '/Users/G
# ...

# %%
st = obspy.Stream()
PATH = r"C:\Users\Geopersian\Documents\KB\input__extract\convert_data\darb\2021\11\GT.DARB.BHE_20211118_000000.seed"
st+= obspy.read(PATH)
st.plot()

# %%
st = obspy.Stream()
PATH = r"C:\Users\Geopersian\Documents\KB\input__extract\convert_data\mdad\2021\11\GT.MDAD.BHE_20211118_060000.seed"
st+= obspy.read(PATH)
st.plot()

# %%
st = obspy.Stream()
PATH = r"C:\Users\Geopersian\Documents\KB\input__extract\convert_data\mian\2021\11\GT.MIAN.BHE_20211118_000000.seed"
st+= obspy.read(PATH)
st.plot()

# %%
st = obspy.Stream()
PATH = r"C:\Users\Geopersian\Documents\KB\input__extract\convert_data\tnbl\2021\11\GT.TNBL.BHE_20211118_000000.seed"
st+= obspy.read(PATH)
st.plot()

# %%
st = obspy.Stream()
PATH = r"C:\Users\Geopersian\Documents\KB\output_extract\2021-11-18T00-31-09.mseed"
st+= obspy.read(PATH)
st.plot()
